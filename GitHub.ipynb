# %% [markdown]
# # GitHub

# %% [markdown]
# * TODO: Add Intro

# %% [markdown]
# ## Step 1: Create a new repository
#
# Open the Github Desktop App and select 'Create new repository' as shown in the picture below.
#
# ![image.png](attachment:560646ea-ff29-4cf5-a056-6108e4db1477.png)
